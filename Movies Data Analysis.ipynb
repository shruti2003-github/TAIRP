# %% [markdown]
# # PROJECT : MOVIES DATA ANALYSIS
#
# AIM : We have to Analyze the Indian Movies Data by using Python Libraries like Numpy, Pandas, Matplotlib and Seaborn with their Mathematical-Statistical functions and interactive visualizations to better understanding the Trends and Patterns.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Loading the datatset

# %%
df=pd.read_csv("IMDb Movies India Data.csv",encoding="ISO-8859-1")
df
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi) -2019.0  109 min            Drama
# 2                             #Homecoming -2021.0   90 min   Drama, Musical
# 3                                 #Yaaram -2019.0  110 min  Comedy, Romance
# 4                       ...And Once Again -2010.0  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga -1988.0      NaN           Action
# 15505                               Zulmi -1999.0  129 min    Action, Drama
# 15506                           Zulmi Raj -2005.0      NaN           Action
# 15507                       Zulmi Shikari -1988.0      NaN           Action
# 15508                        Zulm-O-Sitam -1998.0  130 min    Action, Drama
#
# ...

# %% [markdown]
# ## Basic Information of Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  float64
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 1.2+ MB

# %%
df.shape
# Out:
# (15509, 10)

# %% [markdown]
# ## Checking Null Values

# %%
df.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df["Votes"] = df["Votes"].str.replace(",","")
df["Votes"] = df["Votes"].astype(float)

# %%
df["Duration"] = df["Duration"].str.replace("min","")
df["Duration"] = df["Duration"].astype(float)

# %%
df.rename(columns={'Duration' : 'Duration(min)'}, inplace=True)

# %%
df.describe()
# Out:
#               Year  Duration(min)       Rating          Votes
# count  5659.000000    5659.000000  5659.000000    5659.000000
# mean  -1996.247570     133.439124     5.898533    2697.649585
# std      19.741839      25.319939     1.381165   13651.503584
# min   -2021.000000      21.000000     1.100000       5.000000
# 25%   -2013.000000     119.000000     5.000000      30.000000
# 50%   -2002.000000     135.000000     6.100000     131.000000
# 75%   -1983.000000     150.000000     6.900000     922.500000
# max   -1931.000000     321.000000    10.000000  591417.000000

# %%
df.describe(include='O')
# Out:
#          Name  Genre      Director           Actor 1 Actor 2 Actor 3
# count    5659   5659          5659              5659    5659    5659
# unique   5385    376          2431              1960    2321    2556
# top     Baazi  Drama  David Dhawan  Amitabh Bachchan   Rekha    Pran
# freq        4    844            41               104      52      57

# %% [markdown]
# ## DATA ANALYSIS :

# %%
# Display the records where the duration of the Movies is exactly 200 minutes.

df.loc[(df["Duration(min)"]==200)]
# Out:
#                                              Name    Year  Duration(min)  \
# 11032                                  Prem Nagar -1974.0          200.0
# 12182  Sadiyaan: Boundaries Divide... Love Unites -2010.0          200.0
#
#                          Genre  Rating  Votes          Director  \
# 11032  Drama, Musical, Romance     6.3  114.0  K.S. Prakash Rao
# 12182           Drama, Romance     4.5   75.0        Raj Kanwar
#
#              Actor 1      Actor 2       Actor 3
# 11032  Rajesh Khanna  Hema Malini   Prem Chopra
# 12182          Rekha  Hema Malini  Javed Sheikh

# %%
# Average  Ratings:

df['Rating'].mean()
# Out:
# 5.898533309772045

# %%
# Display the Movie which has high Votes.

Max_vote = df['Votes'].max()
df.loc[(df["Votes"]==Max_vote)]
# Out:
#             Name    Year  Duration(min)                      Genre  Rating  \
# 8219  Life of Pi -2012.0          127.0  Adventure, Drama, Fantasy     7.9
#
#          Votes Director       Actor 1      Actor 2       Actor 3
# 8219  591417.0  Ang Lee  Suraj Sharma  Irrfan Khan  Adil Hussain

# %%
# Find The Movie details in which Akshay Kumar & Katrina Kaif worked together. 

df.loc[(df["Actor 1"]=='Akshay Kumar') & (df["Actor 2"]=='Katrina Kaif')]
# Out:
#                          Name    Year  Duration(min)                   Genre  \
# 5918   Humko Deewana Kar Gaye -2006.0          155.0          Drama, Romance
# 9937          Namastey London -2007.0          128.0  Comedy, Drama, Romance
# 13243           Singh Is King -2008.0          135.0   Action, Comedy, Crime
# 13882          Tees Maar Khan -2010.0          135.0           Comedy, Crime
# 15032                 Welcome -2007.0          159.0         Comedy, Romance
#
#        Rating    Votes             Director       Actor 1       Actor 2  \
# 5918      5.2   3977.0           Raj Kanwar  Akshay Kumar  Katrina Kaif
# 9937      7.1  20942.0  Vipul Amrutlal Shah  Akshay Kumar  Katrina Kaif
# 13243     5.7  14526.0         Anees Bazmee  Akshay Kumar  Katrina Kaif
# 13882     2.6  11981.0           Farah Khan  Akshay Kumar  Katrina Kaif
# 15032     6.9  19527.0         Anees Bazmee  Akshay Kumar  Katrina Kaif
#
#               Actor 3
# 5918     Bipasha Basu
# 9937     Rishi Kapoor
# ...

# %%
# Display movies directed by Mahesh Bhatt received more than 1000 votes.

df.loc[(df['Director']=="Mahesh Bhatt") & (df['Votes']>=1000)]
# Out:
#                          Name    Year  Duration(min)  \
# 484                  Aashiqui -1990.0          152.0
# 1283                     Arth -1982.0          138.0
# 2691                  Chaahat -1996.0          151.0
# 3849   Dil Hai Ki Manta Nahin -1991.0          154.0
# 4259                Duplicate -1998.0          164.0
# 5861    Hum Hain Rahi Pyar Ke -1993.0          163.0
# 12096                Saaransh -1984.0          137.0
# 12170                   Sadak -1991.0          134.0
# 12171                 Sadak 2 -2020.0          133.0
# 15341                   Zakhm -1998.0          125.0
#
#                           Genre  Rating    Votes      Director  \
# 484     Musical, Drama, Romance     6.3   1661.0  Mahesh Bhatt
# 1283             Drama, Romance     7.9   1308.0  Mahesh Bhatt
# 2691             Drama, Romance     5.5   2676.0  Mahesh Bhatt
# 3849   Adventure, Comedy, Drama     7.3   4087.0  Mahesh Bhatt
# ...

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=df['Name'][0:20], y=df['Duration(min)'][0:20], data=df)
plt.title('Movies Name')
plt.ylabel('Movies Duration in minutes')
plt.xticks(rotation=90) 
plt.show()

print(("*")*125)
print("\t\t\t\t\t\t**************ANALYSIS***************\n\n~~  The plot displays the duration of the first 20 movies in the dataset. It indicates that the movie durations vary widely, with some being significantly longer or shorter than others.") 
print(("*")*125)
# Out:
# *****************************************************************************************************************************
# 						**************ANALYSIS***************
#
# ~~  The plot displays the duration of the first 20 movies in the dataset. It indicates that the movie durations vary widely, with some being significantly longer or shorter than others.
# *****************************************************************************************************************************

# %%
# show Top 10 Actors:

top_actors = pd.concat([df['Actor 1'], df['Actor 2'], df['Actor 3']]).value_counts().head(10)
print(top_actors)
# Out:
# Mithun Chakraborty    160
# Amitabh Bachchan      148
# Dharmendra            146
# Ashok Kumar           124
# Akshay Kumar          120
# Shashi Kapoor         117
# Jeetendra             116
# Sanjay Dutt           101
# Rekha                  92
# Ajay Devgn             92
# dtype: int64

# %%
# Find Maximum and Minimum Ratings:

Max = df['Rating'].max()
print(f'Max Rating:{Max}')

Min = df["Rating"].min()
print(f"Min Rating:{Min}")
# Out:
# Max Rating:10.0
# Min Rating:1.1

# %%
# Display High rated Movie: 

df.loc[(df["Rating"]==Max)]
# Out:
#                  Name    Year  Duration(min)           Genre  Rating  Votes  \
# 8339  Love Qubool Hai -2020.0           94.0  Drama, Romance    10.0    5.0
#
#              Director    Actor 1         Actor 2              Actor 3
# 8339  Saif Ali Sayeed  Ahaan Jha  Mahesh Narayan  Rajasree Rajakumari

# %%
# Display lowest rated Movie: 

df.loc[(df["Rating"]==Min)]
# Out:
#           Name    Year  Duration(min)          Genre  Rating    Votes  \
# 12171  Sadak 2 -2020.0          133.0  Action, Drama     1.1  67785.0
#
#            Director     Actor 1        Actor 2      Actor 3
# 12171  Mahesh Bhatt  Alia Bhatt  Priyanka Bose  Sanjay Dutt

# %%
# Top 10 Highly Voted Movies: 

Top_10=df.sort_values("Votes",ascending=False).head(10)
Top_10
# Out:
#                          Name    Year  Duration(min)  \
# 8219               Life of Pi -2012.0          127.0
# 75                   3 Idiots -2009.0          170.0
# 8233                     Lion -2016.0          118.0
# 4848                   Gandhi -1982.0          191.0
# 14038  The Darjeeling Limited -2007.0           91.0
# 8228      Like Stars on Earth -2007.0          165.0
# 10882                      PK -2014.0          153.0
# 3410                   Dangal -2016.0          161.0
# 11463                   Radhe -2021.0          135.0
# 3829              Dil Bechara -2020.0          101.0
#
#                            Genre  Rating     Votes              Director  \
# 8219   Adventure, Drama, Fantasy     7.9  591417.0               Ang Lee
# 75                 Comedy, Drama     8.4  357889.0       Rajkumar Hirani
# 8233            Biography, Drama     8.0  220526.0           Garth Davis
# 4848   Biography, Drama, History     8.0  220118.0  Richard Attenborough
# ...

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['Votes'],hist=False)
plt.show()

print(("*")*125)
print("\t\t\t\t\t\t**************ANALYSIS***************\n\n~~  The distribution plot shows that the majority of movies in the dataset have a relatively low number of votes, with a peak around the lower end of the vote count. This suggests that while some movies may receive a high number of votes, the majority have fewer votes, indicating varying levels of popularity among the movies in the dataset..") 
print(("*")*125)
# Out:
# *****************************************************************************************************************************
# 						**************ANALYSIS***************
#
# ~~  The distribution plot shows that the majority of movies in the dataset have a relatively low number of votes, with a peak around the lower end of the vote count. This suggests that while some movies may receive a high number of votes, the majority have fewer votes, indicating varying levels of popularity among the movies in the dataset..
# *****************************************************************************************************************************

# %%
# Find the Movies names, rates and votes.

df[['Name','Genre','Rating','Votes','Director']].loc[(df['Genre']=='Horror, Mystery, Thriller')]
# Out:
#                                      Name                      Genre  Rating  \
# 8                      ?: A Question Mark  Horror, Mystery, Thriller     5.6
# 1378                            Aur Kaun?  Horror, Mystery, Thriller     6.0
# 2272                                Bhoot  Horror, Mystery, Thriller     6.5
# 2287                        Bhoot Returns  Horror, Mystery, Thriller     2.5
# 2289   Bhoot: Part One - The Haunted Ship  Horror, Mystery, Thriller     5.4
# 4547                                 Ekta  Horror, Mystery, Thriller     8.0
# 4578                             Evil Eye  Horror, Mystery, Thriller     4.7
# 10278                         Number Game  Horror, Mystery, Thriller     6.3
# 11788                                Raqt  Horror, Mystery, Thriller     4.3
#
#         Votes            Director
# 8       326.0       Allyson Patel
# 1378     24.0        Shyam Ramsay
# 2272   3476.0     Ram Gopal Varma
# 2287    513.0     Ram Gopal Varma
# ...

# %%
# Identify movies directed by directors whose names contain "Dhawan" and have a rating of 3 or lower.

df[['Name','Director','Actor 1','Actor 2','Actor 3']][df['Director'].str.contains('Dhawan',case=False)].loc[(df['Rating']<=3)]
# Out:
#                Name      Director       Actor 1        Actor 2         Actor 3
# 3232   Coolie No. 1  David Dhawan  Varun Dhawan  Sara Ali Khan    Paresh Rawal
# 11793       Rascals  David Dhawan    Ajay Devgn    Sanjay Dutt  Kangana Ranaut

# %%
print(df[['Rating','Votes']])

plt.figure(figsize=(8, 6))
plt.scatter(x=df['Rating'][0:20], y=df['Votes'][0:20])
plt.title('Rating vs. Votes')
plt.xlabel('Rating')
plt.ylabel('Votes')
plt.xticks(rotation=90)
plt.yticks(rotation=90)
plt.grid()
plt.show()

print(("*")*125)
print("\t\t\t\t\t\t**************ANALYSIS***************\n\n~~  The scatter plot illustrates the relationship between the ratings and votes for the first 20 movies in the dataset. It appears that there is no clear correlation between the two variables based on this visualization. However, further analysis may reveal patterns or trends in the entire dataset.") 
print(("*")*125)
# Out:
#        Rating   Votes
# 1         7.0     8.0
# 3         4.4    35.0
# 5         4.7   827.0
# 6         7.4  1086.0
# 8         5.6   326.0
# ...       ...     ...
# 15493     6.1   408.0
# 15494     6.2  1496.0
# 15503     5.8    44.0
# 15505     4.5   655.0
# 15508     6.2    20.0
#
# [5659 rows x 2 columns]
# *****************************************************************************************************************************
# 						**************ANALYSIS***************
#
# ~~  The scatter plot illustrates the relationship between the ratings and votes for the first 20 movies in the dataset. It appears that there is no clear correlation between the two variables based on this visualization. However, further analysis may reveal patterns or trends in the entire dataset.
# *****************************************************************************************************************************

# %%
# Top 5 Movies Director has high rates.

top_directors = df.groupby('Director')['Rating'].mean().sort_values(ascending=False).head(5)
print(top_directors)
# Out:
# Director
# Saif Ali Sayeed    10.0
# Sriram Raja         9.7
# Munni Pankaj        9.4
# Suhrud Godbole      9.4
# Arvind Pratap       9.4
# Name: Rating, dtype: float64

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation by Heatmap')
plt.show()

print(("*")*125)
print("\t\t\t\t\t\t**************ANALYSIS***************\n\n~~  The heatmap visualizes the correlation between different numerical columns in the dataset. The annotation of correlation coefficients helps to interpret the strength and direction of relationships between variables. Stronger correlations are indicated by darker shades, while lighter shades represent weaker correlations.") 
print(("*")*125)
# Out:
# *****************************************************************************************************************************
# 						**************ANALYSIS***************
#
# ~~  The heatmap visualizes the correlation between different numerical columns in the dataset. The annotation of correlation coefficients helps to interpret the strength and direction of relationships between variables. Stronger correlations are indicated by darker shades, while lighter shades represent weaker correlations.
# *****************************************************************************************************************************

# %%
sns.pairplot(df)
plt.show()

print(("*")*125)
print("\t\t\t\t\t\t**************ANALYSIS***************\n\n~~  This Visualization shows that Collection of Charts which represents the relation between Variables of data, trends and patterns as well.") 
print(("*")*125)
# Out:
# *****************************************************************************************************************************
# 						**************ANALYSIS***************
#
# ~~  This Visualization shows that Collection of Charts which represents the relation between Variables of data, trends and patterns as well.
# *****************************************************************************************************************************

# %%
plt.figure(figsize=(6,8))
sns.countplot(data=df,y=df['Genre'][0:30])
plt.xticks(rotation=90)
plt.show()

print(("*")*125)
print("\t\t\t\t\t\t**************ANALYSIS***************\n\n~~  The count plot provides the distribution of movie genres in the dataset. It visualizes the frequency of each genre, allowing for easy comparison and identification of the most prevalent genres. Here, we can observe the popularity of different genres and their relative representations.") 
print(("*")*125)
# Out:
# *****************************************************************************************************************************
# 						**************ANALYSIS***************
#
# ~~  The count plot provides the distribution of movie genres in the dataset. It visualizes the frequency of each genre, allowing for easy comparison and identification of the most prevalent genres. Here, we can observe the popularity of different genres and their relative representations.
# *****************************************************************************************************************************
